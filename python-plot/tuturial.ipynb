# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')



autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
fig.savefig('line_plot.pdf')
plt.plot([1, 2], [3, 4])

plt.savefig("plots.pdf")

# %%
import numpy as np

N = 5
men_means = (20, 35, 30, 35, 27)
women_means = (25, 32, 34, 20, 25)
patterns = [ "|" , "\\" , "/" , "+" , "-", ".", "*","x", "o", "O" ]

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, men_means, width, label='Men', hatch = '//')
plt.bar(ind + width, women_means, width, label='Women', hatch = '\\')

plt.ylabel('Scores')
plt.title('Scores by group and gender')

plt.xticks(ind + width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5696444da278> in <module>
#       8 ind = np.arange(N)
#       9 width = 0.35
# ---> 10 plt.bar(ind, men_means, width, label='Men', hatch = '//')
#      11 plt.bar(ind + width, women_means, width, label='Women', hatch = '\\')
#      12
#
# NameError: name 'plt' is not defined

# %%
# Input data; groupwise
green_data = [16, 23, 22, 21, 13, 11, 18, 15]
blue_data =  [ 3,  3,  0,  0,  5,  5,  3,  3]
red_data =   [ 6,  6,  6,  0,  0,  0,  0,  0]
black_data = [25, 32, 28, 21, 18, 16, 21, 18]

labels = ['XI', 'XII', 'XIII', 'XIV', 'XV', 'XVI', 'XVII', 'XVIII']
patterns = [ "|" , "\\\\" , "////" , "+" , "-", ".", "*","xxx", "o", "O" ]

# Setting the positions and width for the bars
pos = list(range(len(green_data))) 
width = 0.15 # the width of a bar
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(10,6))

bar1=plt.bar(pos, green_data, width,
                 alpha=1,
                 #color='w',
                 hatch=patterns[1], # this one defines the fill pattern
                 label=labels[0],
                 edgecolor='k', linewidth=2)

plt.bar([p + width for p in pos], blue_data, width,
                 alpha=0.5,
                 #color='w',
                 hatch=patterns[2],
                 label=labels[1],
                 edgecolor='k', linewidth=2)
    
plt.bar([p + width*2 for p in pos], red_data, width,
                 alpha=0.5,
                 #color='k',
                 hatch=patterns[7],
                 label=labels[2],
                 edgecolor='k', linewidth=2)

plt.bar([p + width*3 for p in pos], black_data, width,
                 alpha=0.5,
                 #color='w',
                 hatch='**',
                 label=labels[3],
                 edgecolor='k', linewidth=2)


# Setting axis labels and ticks
ax.set_ylabel('Number of Switching')
ax.set_xlabel('Strategy')
ax.set_title('Grouped bar plot')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(labels)

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*5)
plt.ylim([0, max(green_data + blue_data + red_data) * 1.5])

# Adding the legend and showing the plot
plt.legend(['OLTC', 'SVC', 'SC', 'OLTC+SC+SVC'], loc='upper right')
plt.grid()
plt.savefig('default.pdf')
plt.show()
